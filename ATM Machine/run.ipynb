# %%
from AtmMachine import Atm

# %%
Atm.counter
# Out:
# 1

# %%
Sonali.sl
# Out:
# 1

# %%
Rupali = Atm()

# %%
Rupali.sl
# Out:
# 2

# %%
Sonali._Atm__balance
# Out:
# 600

# %%
Sonali.balance
# Out:
# 'oiejfd'

# %%
Sonali.deposit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Sonali.deposit()
#
# File d:\OneDrive-UMaine\OneDrive - University of Maine System\GitHub\Python-Projects\ATM Machine\AtmMachine.py:50, in Atm.deposit(self)
#      48 if (self.check_pin()):
#      49     amount = int(input("Enter deposit amount: "))
# ---> 50     self.balance += amount
#      51     print(f"Deposit Successfull and your current balance is {self.balance} ")
#      52 else:
#
# TypeError: can only concatenate str (not "int") to str
